# %% [markdown]
# # Isolation Forest (Anomaly Detection)

# %% [markdown]
# We use isolation forest to find outliers. Unlike decision trees this will try to isolate the data points to capture the outliers.
#
# The data we will use is different from that of our instructor as he didnt provide it. So we will perform this on our own with the 'HealthCare Provider' dataset from kaggle to detect fraud cases in the data.
#
# **You can check DBSCAN lesson. We also learned to detect anomaly by focusing on the outliers**
